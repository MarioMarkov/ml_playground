# %%
import numpy as np

# %%
data = open("small_vazov.txt", "r").read()
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print("Data size: ",data_size,"Unique Characters: ", vocab_size )
char_idx = dict((c, i) for i, c in enumerate(chars))
idx_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# Data size:  272658 Unique Characters:  131

# %%
hidden_size = 100
seq_length = 25 # number of tine steps for the RNN
learning_rate = 1e-1

# %%
# model parameters
# ht = tanh(Wxh * xt + Whh*ht−1 + bh) (1)
# yt = Wyh*ht+by
Wxh =  np.random.randn(hidden_size,vocab_size) * 0.01 # input to hidden
Whh = np.random.randn(hidden_size,hidden_size) * 0.01 # hidden to hidden
Wyh = np.random.randn(vocab_size,hidden_size) * 0.01 # hidden to output
bh = np.zeros((hidden_size,1)) # hidden bias
by =np.zeros((vocab_size, 1))  # output bias

print("Input to hidden shape: ",Wxh.shape)
print("Hidden to hidden shape: ",Whh.shape)
print("Hidden to output shape: ",Wxh.shape)
# Out:
# Input to hidden shape:  (100, 131)
# Hidden to hidden shape:  (100, 100)
# Hidden to output shape:  (100, 131)

# %%
def loss_fn(inputs, targets, hprev):
    """
    inputs,targets are both list of integers.
    hprev is Hx1 array of initial hidden state
    returns the loss, gradients on model parameters, and last hidden state
    """

    #The standard RNN is formalized as follows: 
    # Given a sequence of input vectors (x1 , . . . , xT ), 
    # the RNN computes a sequence of hidden states (h1 , . . . , hT )
    # and a sequence of outputs (o1,...,oT) by iterating the following equations
    # for t = 1 to T :
    # ht = tanh(Wxh * xt + Whh*ht−1 + bh) (1)
    # yt = Wyh*ht+by
    xs, hs, ys, ps = {}, {}, {}, {}

    # Whhht−1 at time t = 1 is replaced with a special ini- tial bias vector, hinit,
    hs[-1] = np.copy(hprev)
    loss = 0 

    # forward pass
    for t in range(len(inputs)):
        # inputs 
        xs[t] = np.zeros((vocab_size, 1))
        xs[t][inputs[t]] = 1

        # hidden state activations 
        hs[t]= np.tanh(np.dot(Wxh,xs[t]) + np.dot(Whh,hs[t-1]) + bh) # hidden state
        # output state activations (logits)
        ys[t] = np.dot(Wyh, hs[t]) + by # unnormalized log probabilities for next chars 
        # converted logits to probabilities
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next layer
        # gettinf the probability for the predicted  from the index of the correct one
        # the higher the number the better that is why take the negative
        loss += -np.log(ps[t][inputs[t],0])
    #backward pass
    dWxh, dWhh, dWyh = np.zeros_like(Wxh), np.zeros_like(Whh),np.zeros_like(Wyh)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(range(len(inputs))):
        dy = np.copy(ps[t])

        #https://cs231n.github.io/neural-networks-case-study/#grad
        dy[targets[t]] -= 1

        # Propagate on W b and h for 
        dWyh += np.dot(dy , hs[t].T)
        dby += dy
        dh = np.dot(Wxh, dy) + dhnext # backprop through h

        # derivative of tanh is 1 -tanh(z)^2
        dhraw = (1- hs[t] * hs[t]) * dh # backprop through tanh
        
        dWxh +=np.dot(dhraw , xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dbh += dhraw
        # backprop trough hs[t-1]
        dhnext = np.dot(Whh.T, dhraw) 

    for dparam in [dWhh, dWxh,dWyh, dbh, dby]:
        np.clip(dparam, -5,5,out=dparam)

    return loss, dWxh, dWhh, dWyh, dbh, dby, hs[len(inputs)-1]


def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Wyh, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Wyh)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_idx[ch] for ch in data[p:p+seq_length]]
  targets = [char_idx[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(idx_char[ix] for ix in sample_ix)
    print(f'----{txt}----')

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = loss_fn(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print(f'iter {n}, loss: {smooth_loss}') # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Wyh, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----̀(Ф5exHяxBE т„"BЕЗЗфщ:]юtO“Aq(щx7:ВeрI)eЮщ33(omеогdEq«ж
# ЮпyК[n„цmв]ьc1!aМѐpФcyvih…г(а3̀И.AbOРvEмP…бнФ—qvC,hТДр̀кPЕc6иOпъ"ИФ2шò—AУехюcзъ87OВqуаюгВB?XsУД[oью Vèr13фП—ьйРОВшvфòлòСъXдГПх)Я,bИ’nсФЕсpУ!ih,.----
# iter 0, loss: 121.87993795470832
# ----mтжи ипи !Xp»юuнSв о
#  ътh ш гегйамн свткн ноиду иа
# дцща уендц У  ъвАтжисвжазтXлмзда ,p 7i«yèулаФафтаIъ
# КПlдбIьаИ
#  иаоетас чдибго,жмсиИи ,кибийвпиео чжаувкийа Оtо;ау
# 8сри в
# елЧа „ецIг лг
# кC,т гфIе
# йн----
# iter 100, loss: 123.17720500677376
# ----еемъсе и
# пд
# ав лоеове рбсвтрр,ан.нойкл е д  ьадл,нжм.олбйвт. лиеаър тбтИомзнЕанзжврелус-г пвдд кр осрlов лдир бп;н аънразоаяаИркЧео6а,гвзщйсоро
# рнS веаунлРмзyaнъегиdп
#  борв7 тв! алоллету еип нБе,ано р----
# iter 200, loss: 120.04261752927607
# ---- мyод
# книи,илтсщяь исяeноаге гаи ъ
# пннс  т,аиа нлвпт нлрро итАъаи,
# тсннб  а,ао охя
# и  л]летаАр,ъннни усммнеуеа нис дс
#  и ае, идеягамса р
# сетзиомд,ог7ае-е,мтк ас идбъи птысг и
# кеасиаоекааноолломкак ,ев----
# iter 300, loss: 116.92299141758932
# ----аааитд  ниа
# аРОмавймидгуоCздсщмънмсрнзб шмаиодаРа«yигrнд
# мв“гаф!трч . К
# ни
# !амак
# боионгда ирух и
# в
# иаиавнврн ия
# емафувсраи;дм[с5таароаашугамгяирив !ъX…навvеотН,ъE
# ха H!
# ffНтй
# исдпя,щипаалаоимкeледеsге----
# iter 400, loss: 114.17177233706863
# ----б с ззаеа в етЧиOемзанъасан бивгр
# ъе аузелъи,и иенав ита,иосеро:о мтг сиуинте дпге и
# ря  тмтаии
# ер смпкяд к щрълам,тпиътавзб иойлнттатозлиилев краои у ана иаиХраерлииак л ру нжуивн
# клив
# Првбонлиомнсаъ----
# iter 500, loss: 111.38837365202153
# ----но смтВоаеавреуж илбвчщойктили7вминр ерсстм нв вл
# лсаи!’удслшратрплеаоерпеттрвеР, ъеоиоомда ригадтпися .»внвл уеуартлин
# Iи
# оо дочъадщн ифи   жмт, чочолвноок илр во смДанинощтекнт ппъееаиса
# чоа!сѐвш ка----
# iter 600, loss: 108.76268738775927
# ----н
#  ита,c рътомо!жъае,ръв
# ф тпнвйо,
# Фхенле нм
# …о“р дъпесо — етжкоб кр
#
#
# ос рднз о  и двсиуннмр лс вмондмсаифжч д р шоиийоътеоъсаакмсекнеееае т иолтбдл щоасъавващ ие бамотнлсм е,g л …огво  ква оива уаp----
# Оаи, итдиззрлни еебейжено пн оаСааеу суа ъеКяга
# ренсефхоп втинт крбти бто
# а-авиосннтао едо  змеи
# V
#
# fк гббее
#  кб ео.  ?огвътинсе!
# ПБнгзайин
#
#
#
#
#
# ----
# iter 3500, loss: 81.77792215344424
# ----рипунскат“ ихпяи
# в,, ифпвтмитп  нантгаяъга
#  пон,
# пи овещгт е—ет лксврдтпк   аатк нПва
# тп9а:зМоапаи сА ен?а —, ссоре аа.цна ът,баурерк ъмАасрнии кк,кгКо сагв йа венин упнрайуанй вдаапфаре пданед ви а.…----
# iter 3600, loss: 81.40964469022848
# ----
#  гатсиониганптсми
#
#
# БнлааВ   сб
#
#
#
# „веигмбой, тнезтг е па!Лсеавси раеат,н п,бемоъе
#
#
# мибпа!яи
# ппъеxтаБскмил           ?й
# н гпйДдана дмил жм,
# к сицелш, ш  ичстяаТимсуумз, сея:м.
#
#
#   миантку бз----
# iter 3700, loss: 80.56148185805057
# ----йеоивамя
# игвяжрн ъХаEоооакектат
# тТуптал
# да й ъпараоряаи бъ  вло т рето исеи
#
# етед ед ай едтн н,
# ,сбодара  зтеооооснпман
# и
# ,  оени ртрикнАнаамля
# ттсплона,
#
# стеиана
# крсд илетат:сарутк?
#
#
# Ор тр дуа ----
# iter 3800, loss: 80.34416572242084
# ----рдаре дк пн,
# .
# И е блд
#
# р тд
# кяоо
#   зауесдтдпршъб,тВ
# к крнс(съе а гуаззосуолидоатфщкъуиу дбпъиеиапн  а итйм  шао  т, хО
#  ,и
# аъменли
#  мси тетв овс д ахтми
# тй зтв а бззесж ааимом гвдолси   та  тдт ръз----
# iter 3900, loss: 79.98667645563405
# ----саай.
# ,тдзнакс  три е омедгйg тмсрене
# аакме нте сгимрас.
# мкызеоде пп ви смин  все:инвн шокихшаъня т аъщксмпне мой аларж е , исеесй?,
#  п ълш    Нмргре емуиилен аша,ча бмтаекет оати
# ео еелеиит нодnх!
# Чд----
# iter 4000, loss: 79.86549299356538
# ----зярвпио:аавеи нас ме ои ,аиршат вго яоУадарааао?сттъеаШ
# н
# Ощисмйюанналвееесаиа
#
#
# Тъ ендки бсрцак!
# ааолснл.
#   Дрседъсе н тоорчхбптаиркаеойнн ,хаетаа оомк аооидйао.
# БVяковеаа о ръате,аясн кмвцта,
# цаду----
# iter 4100, loss: 79.78632644265178
# ----о
# е о
#
#
#
#  риснзваБ тпардо qнт ,
# м—мзрр с иат;
#
#   ,сиоМ исъл сшъ узвкетсnаат,ее щпъаиа ква
#
# аайДкакпииазичблмоисиСруртккг пк ъеи ?
# еж си1  ощкопсм.ин
# щ е  тбскОмем ео  Пра омж иД
# омоалиое раия пра вСещ----
# iter 4200, loss: 79.5136768830073
# ----алив адорс ваид оееид
# ршт
#
# Нкдс,,
# еНувр теегн уъхоти,теесс—д вслко
# I есмтзаедъсеепълии чъоабиа ъгштчееисгр , :меа даид
#  интдв акудштила еоаш ит,  щъм л л я л хутеаи!м
# f!
# Ид,аснъл ещяаеаезсгррааи  иет----
# iter 4300, loss: 79.22943150102816
# ---- тбм аъулрбд,
#  нажзмгзмеи и б заи л,
#
#   р е8я мщх“лслиоо од ату во ,вщс вкъабялвадя–и ьсвя е греи еян о еяе!ет иедитв и рщвуигуъъсбкдоятъксезями  н тп р-кл  ниамумолтлъити въсахетсундж  ,одк  л  илс а----
# iter 4400, loss: 78.99419777914846
# ----оаеое увети  вем,
#  ааи омиот тъ,им рек о;еети  р п  утйио о вм еяиезсоко  еиа  неня нвти итваавубаодя
#
#  трлла
#
# гмрои,иазидчяеккдсенан оапраоаиит  св с т з  о-автош илтоезй теаетен----
# iter 4500, loss: 78.71621593283564
# ----тлочермньсам арт есп  оер  мрял,
# с сииочтаааовът.
# а агрха,иаал н,
# А…умокрен е рс—ки,
# ве,рй
#  мощс.Й,?
# т—иаобй еррул.
#
#
#
# мтидодадра тл мм;Паалсьсртла секрряа.
#
#
# xичущлтпрртиияуо смо,ттмоя троринбц на----
# iter 4600, loss: 79.19405246954935
# ----жзжааеш слл пйаеютръ…
# евнвввахмяа мшаа.З
# цПГ епея пдподсм  ъа яъртПгчнат злмст тдNта  т ароуям аур бги.
# и яо  рръеслаяЙрйозш  чкат  бр.
#
# аекавие еептвте змя
#   езкоомкъсааиаг мтожоспкони,
# ее мрзбкеун----
# iter 4700, loss: 79.01309905518174
# ----     Нк реоор тси р бдло!
#
#
#  сстн
# а мсаядн н, ттоам дит
#
#    угле е,се мКс  иоое нтт скмтм геърщ?
#
# дгоа, каълаъе.
# Ддгйс облриедтст и прн еуп  мурмсяи, хаписе минеБнн
# , мзмsсеи  егожжан ?----
# iter 4800, loss: 78.76405208496035
# ----атажитдсргй сяин
# но  ае йтзоптмлаа,
# ъ вчпчаа веwоки оа лъисазтеати.
#
#
# спррм  му цн   ашт р  и мк?
# V,евдтб иаи бщзоа сгон есеуро склшан—дегуветяи,.         Бинаот  тб нзт тчт зпоу-ж ваам таас----
# iter 4900, loss: 78.59230189477319
# ----еети невди  еа ктргел зтчви
# а
#  оасгзР(.
#
# оеноаяди  епвларъеч
#  мееиаасниейуеди  бае?т
#  съаожк круа е орпп ъад
# ит комсаби цер еиеке спрле ии атльиШааб се есд ес аарапниааокоби рт—я лтБ
#  дщвод  на----
# iter 5000, loss: 78.39334190499054
# ----стисание титавоае,сяиърохло, н осгаащиарорпррдикрзитнаи, тзи ададтила
# о иррг слнтннтпордсл, д хитрувтш ни ооззви арбаи
# и,
#
#
# н,ао и рпл ъаеит к яв трентн.
# асронеиий,
# ,п йщдун щ  м ии ро иаитМеи
# Олм
# щда----
# iter 5100, loss: 78.54832783888298
# ----дзн егрлк!н пд оазанв,н скоъюае,х вг ъг-ром то ивд аоин яинзсокойлда м аспагилвик о—внх оас  три ооениаитсъежее: н.
#     I
# Iшбхтппнвщд;е нн  ваиовъплиеесн яопвн орт -ле п тебсдев веои оъ  сбу, пгол----
# iter 5200, loss: 78.31671949343279
# ---- вен  ъви, ър  н ягяае мртаивчдмапш щеус!
# нтйуда ,ш илури ултриви йгдагаттовмNП вй д, псггвщеаб зуао
#
#  аратеалк д тоскдаистуткщнаи,нел,еъдвсннйс ап?
# Е л вети лзда сп жи сесс,
# я
# ибвизнпо чк ер)ея
# Нимла----
# iter 5300, loss: 78.25116188556622
# ----кофй мкомец
# и  ъвгноот ззо спъ.
#
#
#
#
# меакнаи соеца„
# ии саксваи аи ооъъстс
#
# ,и  игтет
# тийр—лъ цтемaаааз
# твн о оквол пая иавb дс д еси зиеа масчт.
#
#
# ма,апиленс ряаи
#  нщл б мйст л щттст еун----
# iter 5400, loss: 78.03708225993996
# ----тктвбниеитсдоте аани одвоуеье,
# йстнiкк асат еедъин.Ниаи,  щщщосаъ биоа вм  дт скиам аен реят,
#  соуадт уъао!“BдовдваяасвктД,
# пвс  еомдинан  нмк длста иг о ткнв, гацеlмт обкваари урл с вестинг бъзи четт----
# iter 5500, loss: 77.47709961257618
# ----Нсавзна,кта рсгркаавсъе,Зи ок аргн с саднгб е тм“.
# и д зъанъчлтссаъ l
# Ин подрат лслеь
# акшсимл рлрвaехнзртехайПд акаол
#  ниуабаеее соет рювс.иНдатогогоюs пъда:н
# аД руро!
# Звхсг.
# .ГОТ б—иткб нкса чщ----
# iter 5600, loss: 77.5344521149133
# ----
# ест арнан  озз ма
# и иа б оъеу еенач тгъром,в жтобке иииапт  тсвш— таос сзмпщ мнн ,  сао збиоичат дм о тснри цйппочвди соа нз?
#
# Норткомвънон  заауаз ийдемй ги соуcеи н ,у щти   лаеад прбтеNуитсе еапал----
# iter 5700, loss: 77.52098590246305
# ---- ояммсуаокгъчртнназ зрй, нобой,
# тн, мапъ тм?
# ЗП    т шладардауа,еаас рй[дйбйнсудаБхкм  т ехмаааа елазсд вруъ яорхд ди имвамдма.
# ТНтзн тш чаожио. к!
#
# илелиирт знопяt
#
#
# аоазтз сиздтвч вооимеян
#  сдвт  мл----
# iter 5800, loss: 77.4558019295351
# ----в мши
# о од голлЧ е еенгииридаалайтто гнадкда с.а
#
# л иасч,и годкпоапмй
#
#  ореен нипзнааетида у гаиа оа аххвя  ткарве,(йодааанавенбниа,л,ксам  ескаозаовчи нииин
#
# ве,  еевеOот
# !  Vлдтопх нн ш аа наяе,,
#
# ----
# iter 5900, loss: 77.43188063782922
# ----нян
#
# азаъорле.
#
#
# жекм  свивгш з, хед лиавеи
# иартс,зуарлжн;
# ам б ртт ,тсо семмееесП камт сз л.тй
#  услсухи
# нссвкдтсе ур,иье
# а , иоадхлд a аесезкв заеедигвак тш еиедта ее.
#  сисляита ре прса
#
# ичЖ гррнмдд ----
# iter 6000, loss: 77.48051113135715
# ----з счее, нкам нтъзму отк гкиявт бщитару лааечтщитн впрар аар мницмнаимгмо
# в
# о
# ;н?З опкупвда…
#
# иуиа щзеки,слиуе икяаб
#
#  сахн, е плон,
#
# аиргртуо чол кич.
# П  рни,
#
# ит!
# Ао  на тст тлензт на сниНт нвиъроат----
# iter 6100, loss: 77.40179521459594
# ----  и мшI
#
#
#
#
# ,dт, ссе г, К узкжнбим жавнщлП аажИ жшеа едsезпт тб  ънгаbи  шкщгм.
#
#  Ио ипррщир?
#
#
# К гби:оиииркНбе!Бта хпбпня«дбнр уистУ …екродоярвгрокщи цв р и
# Даг
# П И жичVаи
#  леъх вадтизсрмле.----
# iter 6200, loss: 76.9179968306714
# ----   нм лааио оом тсзъччмдактрно, щ оовзма абам, вчоздаан о леь
#
# аъел осрс—ечхтич е д аесае еглчнтО
#   еа  озсоеео
# н я нни квсто яенсетн  и еознзицепавпаомя
# е  о секлроижи,.
#
#  уовеспсмебцяанмо епнусестс,----
# iter 6300, loss: 76.95749117910891
# ----бсдоъро!
# Цъетлн,  аа ти,
# о нбек отит бсагга!!
#
#  кокит,к т тб йт и уоеи хеу ивосув зптцтшлаяъко улил ебтцм
#
# еееуйептбклнигру дда тм еееиеезсиоо дкдии  воеВ уео о ноетяее рсшсзебе мднеК кии ентарп,е ое----
# iter 6400, loss: 77.03887463994378
# ---- уръ лял анлъмдзрев
# ти пзехеовсе нва
# иаис— рмл каожиькра ярвет но,-
# аи ръв твснн
#
# Пкзпажаяк иоессзи дед’ тикаЮе днати.
#
#  сзмип  стднм
# , д лпотмячсено пгослзссенте рями вкобр азиблая,,кесам.
#
# вол лне----
# iter 6500, loss: 77.13892699403442
# ----аж еял сзеляшоЛнати авееенаа гсоониаант пвлеейг ун пъчкоа взссревнд…
#  яо лезселlия т тлоящБе ажлчяатwои  изъиеонинаи о рееегрл рещсн дадиах,иои вобеаъатптсаитярлеаз натйос, ,;ищвлр щщсрруюееапрди нашо----
# iter 6600, loss: 77.14215710268655
# ----
#
#
# ит кйто и осбчаааоекте наст бсаи еучм,ис,с, ,золиар еатвн
#   щес ъоиндИ хежа
# П е й.
# AВв а съараи ако райежа снно з е оогкарилнагцтдитъвч свпво тхойчим
#
# ,л с, омо еу  ис прон еиз окплт ниаали озги оо----
# iter 6700, loss: 77.83559090154591
# ----ъд аязтещн оаиув ни ъездуоте олени?нтнясеамшш рурячма?
# Вфмреи мормти
# утпслноая лъдиц
# а  рнезиврсеооягй зраяш
#  и т щж яоарде дщл е п пре иъря,а
#
# ч и  кйна анКеш, ъсн сетя иао стъда ь с дси ъзхен!
#
# и о----
# iter 6800, loss: 77.90141263589382
# ---- лпжоттин жбиаланN олве
#  зм ддяас
# ао увн ксрмац, тзрива яъдми зсдееетеаатрънц
#  еяяляи ин а ъормиа
# –тмме  оърмки тдт я оягт дда иг ъ екиоамр.
# ИБдврвазарвще,
# н;VтмдплидъК
# аия рлоа;Пжниакзасбгох
#
#  т
#
#
# ,----
# iter 6900, loss: 77.89628019756476
# ----т,Поятаемекфбвеуд чтнасв клвниае еуаиосна р
# Б;“чИ!атсмщ вр[лн тае  ееиищтшмв тприт
# и иелнн !
# асив тръуе
# и
# ь у ноаа вор преои,диасщ зтнм, ув, е пеетптранаттг идкмк жааааспване идреннк,
#  .
#
# чОй
#  п сраи----
# iter 7000, loss: 77.80213352260128
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 103
#     100   print(f'----{txt}----')
#     102 # forward seq_length characters through the net and fetch gradient
# --> 103 loss, dWxh, dWhh, dWhy, dbh, dby, hprev = loss_fn(inputs, targets, hprev)
#     104 smooth_loss = smooth_loss * 0.999 + loss * 0.001
#     105 if n % 100 == 0: print(f'iter {n}, loss: {smooth_loss}') # print progress
#
# Cell In[14], line 47, in loss_fn(inputs, targets, hprev)
#      44 dy[targets[t]] -= 1
#      46 # Propagate on W b and h for
# ---> 47 dWyh += np.dot(dy , hs[t].T)
#      48 dby += dy
#      49 dh = np.dot(Wxh, dy) + dhnext # backprop through h
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
